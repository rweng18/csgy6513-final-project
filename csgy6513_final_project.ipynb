# %% [markdown]
# # Cultural Scorecard in NYC based on the MTA

# %%
# start a Spark session
import pyspark

session = pyspark.sql.SparkSession
# use all available memory for the driver
spark = session.builder.config('spark.driver.memory','10g').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://e2257a301dd5:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Set dataset paths
path = "Final_Data/final_joined_data.csv"

# Function to read in CSV files
def read_data(path):
    df = spark.read\
              .option("header", True)\
              .csv(path)
    df.printSchema()
    return df

# %%
final_df = read_data(path)
# Out:
# root
#  |-- station_complex: string (nullable = true)
#  |-- station: string (nullable = true)
#  |-- Route: string (nullable = true)
#  |-- Borough: string (nullable = true)
#  |-- GTFS Stop ID: string (nullable = true)
#  |-- Division: string (nullable = true)
#  |-- CBD: string (nullable = true)
#  |-- total_ridership: string (nullable = true)
#  |-- transit_date: string (nullable = true)
#  |-- str_Coordinates: string (nullable = true)
#  |-- cultural_landmark: string (nullable = true)
#  |-- historical_place: string (nullable = true)
#  |-- monument: string (nullable = true)
#  |-- museum: string (nullable = true)
#  |-- performing_arts_theater: string (nullable = true)
#  |-- sculpture: string (nullable = true)
#  |-- art_gallery: string (nullable = true)
#  |-- art_studio: string (nullable = true)
#  |-- auditorium: string (nullable = true)

# %%
final_df.limit(5).toPandas()
# Out:
#             station_complex             station Route Borough GTFS Stop ID  \
# 0  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
# 1  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     F      Bk          D42
# 2  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
# 3  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     F      Bk          D42
# 4  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
#
#   Division    CBD total_ridership             transit_date  \
# 0      BMT  False          2310.0  2025-07-10T00:00:00.000
# 1      BMT  False          2310.0  2025-07-10T00:00:00.000
# 2      BMT  False          2854.0  2025-07-09T00:00:00.000
# 3      BMT  False          2854.0  2025-07-09T00:00:00.000
# 4      BMT  False          3430.0  2025-07-05T00:00:00.000
#
#            str_Coordinates cultural_landmark historical_place monument museum  \
# 0  (40.576127, -73.975939)               1.0              5.0      1.0    2.0
# 1  (40.576127, -73.975939)               1.0              5.0      1.0    2.0
# 2  (40.576127, -73.975939)               1.0              5.0      1.0    2.0
# 3  (40.576127, -73.975939)               1.0              5.0      1.0    2.0
# 4  (40.576127, -73.975939)               1.0              5.0      1.0    2.0
#
#   performing_arts_theater sculpture art_gallery art_studio auditorium
# 0                     5.0       3.0         5.0        2.0        0.0
# 1                     5.0       3.0         5.0        2.0        0.0
# 2                     5.0       3.0         5.0        2.0        0.0
# 3                     5.0       3.0         5.0        2.0        0.0
# 4                     5.0       3.0         5.0        2.0        0.0

# %%
from pyspark.sql.types import DoubleType, IntegerType
## Convert columns to Double
final_df = final_df.withColumn("total_ridership", final_df["total_ridership"].cast(DoubleType()))\
                   .withColumn("art_gallery", final_df["art_gallery"].cast(DoubleType()))\
                   .withColumn("art_studio", final_df["art_studio"].cast(DoubleType()))\
                   .withColumn("auditorium", final_df["auditorium"].cast(DoubleType()))\
                   .withColumn("cultural_landmark", final_df["cultural_landmark"].cast(DoubleType()))\
                   .withColumn("historical_place", final_df["historical_place"].cast(DoubleType()))\
                   .withColumn("monument", final_df["monument"].cast(DoubleType()))\
                   .withColumn("museum", final_df["museum"].cast(DoubleType()))\
                   .withColumn("performing_arts_theater", final_df["performing_arts_theater"].cast(DoubleType()))\
                   .withColumn("sculpture", final_df["sculpture"].cast(DoubleType()))

# %% [markdown]
# ## Basic Visualizations

# %%
import ipywidgets

unique_complex_day = final_df.dropDuplicates(["station_complex", "transit_date"])
unique_complex = final_df.dropDuplicates(["station_complex"])

# %%
from pyspark import pandas as ps
unique_complex_day_pd = unique_complex_day.toPandas()
# Out:
# /usr/local/spark/python/pyspark/pandas/__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(

# %%
import plotly.io as pio
import plotly.express as px
pio.renderers.default = 'iframe'

# %%
fig = px.histogram(unique_complex_day_pd, x="total_ridership", 
                   title="Histogram of Total Ridership per Station Complex (2025)", 
                   labels={
                     "total_ridership": "Total Daily Ridership"
                     })
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_9.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# !pip install --upgrade kaleido
# Out:
# Requirement already satisfied: kaleido in /opt/conda/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: choreographer>=1.0.5 in /opt/conda/lib/python3.11/site-packages (from kaleido) (1.0.9)
# Requirement already satisfied: logistro>=1.0.8 in /opt/conda/lib/python3.11/site-packages (from kaleido) (1.1.0)
# Requirement already satisfied: orjson>=3.10.15 in /opt/conda/lib/python3.11/site-packages (from kaleido) (3.11.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from kaleido) (23.2)
# Requirement already satisfied: simplejson>=3.19.3 in /opt/conda/lib/python3.11/site-packages (from choreographer>=1.0.5->kaleido) (3.20.1)

# %%
columns = ["art_gallery", "art_studio", "auditorium", "cultural_landmark", "historical_place", 
           "monument", "museum", "performing_arts_theater", "sculpture"]

fig2 = px.box(unique_complex[columns], title="Box Plots of Distribution of Nearby Places by Type", 
                   labels={
                     "variable": "Types of Places"
                     })

fig2.update_layout(
    xaxis = dict(
        tickmode = 'array',
        tickvals = columns,
        ticktext = ["Art Gallery", "Art Studio", "Auditorium", "Cultural Landmark", "Historical Place",
                    "Monument", "Museum", "Performing Arts Theater", "Sculpture"]
    )
)
fig2.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_11.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Add Crowdedness Score

# %%
# Take log of ridership to see if it normalizes
from pyspark.sql.functions import log
final_df = final_df.withColumn("log(ridership)", log(final_df.total_ridership))

# %%
final_df.limit(5).toPandas()
# Out:
#             station_complex             station Route Borough GTFS Stop ID  \
# 0  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
# 1  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     F      Bk          D42
# 2  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
# 3  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     F      Bk          D42
# 4  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
#
#   Division    CBD  total_ridership             transit_date  \
# 0      BMT  False           2310.0  2025-07-10T00:00:00.000
# 1      BMT  False           2310.0  2025-07-10T00:00:00.000
# 2      BMT  False           2854.0  2025-07-09T00:00:00.000
# 3      BMT  False           2854.0  2025-07-09T00:00:00.000
# 4      BMT  False           3430.0  2025-07-05T00:00:00.000
#
#            str_Coordinates  cultural_landmark  historical_place  monument  \
# 0  (40.576127, -73.975939)                1.0               5.0       1.0
# 1  (40.576127, -73.975939)                1.0               5.0       1.0
# 2  (40.576127, -73.975939)                1.0               5.0       1.0
# 3  (40.576127, -73.975939)                1.0               5.0       1.0
# 4  (40.576127, -73.975939)                1.0               5.0       1.0
#
#    museum  performing_arts_theater  sculpture  art_gallery  art_studio  \
# 0     2.0                      5.0        3.0          5.0         2.0
# 1     2.0                      5.0        3.0          5.0         2.0
# 2     2.0                      5.0        3.0          5.0         2.0
# 3     2.0                      5.0        3.0          5.0         2.0
# 4     2.0                      5.0        3.0          5.0         2.0
#
#    auditorium  log(ridership)
# 0         0.0        7.745003
# 1         0.0        7.745003
# 2         0.0        7.956477
# 3         0.0        7.956477
# 4         0.0        8.140316

# %%
fig3 = px.histogram(final_df, x="log(ridership)", 
                   title="Histogram of Log(Total Ridership per Station Complex) (2025)", 
                   labels={
                     "log(ridership)": "Log(Total Daily Ridership)"
                     })
fig3.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_14.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Source: https://stackoverflow.com/questions/68496993/probnorm-function-equivalent-in-pyspark
import pandas as pd
from scipy.stats import norm
from pyspark.sql.functions import udf, col, lit, min, max

# unique_complex_day = final_df.dropDuplicates(["station_complex", "transit_date"])
# unique_complex = final_df.dropDuplicates(["station_complex"])

drop_empty = final_df.filter(col("log(ridership)") >= 6.0) ## Drop extreme values

# %%
unique_complex_day.count()
# Out:
# 8064

# %%
drop_empty.count()
# Out:
# 13298

# %%
# Calculate Min and Max for Log(ridership)
rides_min = drop_empty.select(min(col("log(ridership)"))).collect()[0][0]
rides_max = drop_empty.select(max(col("log(ridership)"))).collect()[0][0]

# Perform Normalization
drop_empty = drop_empty.withColumn("pnorm(ridership)", (col("log(ridership)") - rides_min) / (rides_max - rides_min))

# %%
fig3 = px.histogram(drop_empty, x="pnorm(ridership)", 
                   title="Histogram of Probability Normalized (Total Ridership per Station Complex) (2025)", 
                   labels={
                     "pnorm(ridership)": "PNorm(Total Daily Ridership)"
                     })
fig3.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_19.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Add crowdedness
score_df = drop_empty.withColumn("crowd_score", 10*(1 - col("pnorm(ridership)")))

# %%
fig3 = px.histogram(score_df, x="crowd_score", 
                   title="Histogram of Crowdedness Score (2025)", 
                   labels={
                     "crowd_score": "Crowdedness Score (0-10)"
                     })
fig3.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_21.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
score_df.limit(5).toPandas()
# Out:
#             station_complex             station Route Borough GTFS Stop ID  \
# 0  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
# 1  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     F      Bk          D42
# 2  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
# 3  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     F      Bk          D42
# 4  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
#
#   Division    CBD  total_ridership             transit_date  \
# 0      BMT  False           2310.0  2025-07-10T00:00:00.000
# 1      BMT  False           2310.0  2025-07-10T00:00:00.000
# 2      BMT  False           2854.0  2025-07-09T00:00:00.000
# 3      BMT  False           2854.0  2025-07-09T00:00:00.000
# 4      BMT  False           3430.0  2025-07-05T00:00:00.000
#
#            str_Coordinates  ...  monument  museum  performing_arts_theater  \
# 0  (40.576127, -73.975939)  ...       1.0     2.0                      5.0
# 1  (40.576127, -73.975939)  ...       1.0     2.0                      5.0
# 2  (40.576127, -73.975939)  ...       1.0     2.0                      5.0
# 3  (40.576127, -73.975939)  ...       1.0     2.0                      5.0
# 4  (40.576127, -73.975939)  ...       1.0     2.0                      5.0
#
#    sculpture  art_gallery  art_studio  auditorium  log(ridership)  \
# 0        3.0          5.0         2.0         0.0        7.745003
# 1        3.0          5.0         2.0         0.0        7.745003
# 2        3.0          5.0         2.0         0.0        7.956477
# 3        3.0          5.0         2.0         0.0        7.956477
# 4        3.0          5.0         2.0         0.0        8.140316
#
#    pnorm(ridership)  crowd_score
# 0          0.288724     7.112764
# 1          0.288724     7.112764
# 2          0.323792     6.762083
# 3          0.323792     6.762083
# 4          0.354277     6.457229
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Add Quantity Score

# %%
#                           Weight
# art_gallery	            0.2
# art_studio	            0.1
# auditorium	            0.025
# cultural_landmark	        0.15
# historical_place	        0.05
# monument	                0.1
# museum	                0.3
# performing_arts_theater	0.05
# sculpture	                0.025

quant_df = score_df.withColumn("quant_score", 
                               (col("art_gallery") * 0.2 + col("art_studio") * 0.1 + 
                                col("auditorium") * 0.025 + col("cultural_landmark") * 0.15 + 
                                col("historical_place") * 0.05 + col("monument") * 0.1 + 
                                col("museum") * 0.3 + col("performing_arts_theater") * 0.05 + 
                                col("sculpture") * 0.025))

# %%
quant_df.limit(5).toPandas()
# Out:
#             station_complex             station Route Borough GTFS Stop ID  \
# 0  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
# 1  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     F      Bk          D42
# 2  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
# 3  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     F      Bk          D42
# 4  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
#
#   Division    CBD  total_ridership             transit_date  \
# 0      BMT  False           2310.0  2025-07-10T00:00:00.000
# 1      BMT  False           2310.0  2025-07-10T00:00:00.000
# 2      BMT  False           2854.0  2025-07-09T00:00:00.000
# 3      BMT  False           2854.0  2025-07-09T00:00:00.000
# 4      BMT  False           3430.0  2025-07-05T00:00:00.000
#
#            str_Coordinates  ...  museum  performing_arts_theater  sculpture  \
# 0  (40.576127, -73.975939)  ...     2.0                      5.0        3.0
# 1  (40.576127, -73.975939)  ...     2.0                      5.0        3.0
# 2  (40.576127, -73.975939)  ...     2.0                      5.0        3.0
# 3  (40.576127, -73.975939)  ...     2.0                      5.0        3.0
# 4  (40.576127, -73.975939)  ...     2.0                      5.0        3.0
#
#    art_gallery  art_studio  auditorium  log(ridership)  pnorm(ridership)  \
# 0          5.0         2.0         0.0        7.745003          0.288724
# 1          5.0         2.0         0.0        7.745003          0.288724
# 2          5.0         2.0         0.0        7.956477          0.323792
# 3          5.0         2.0         0.0        7.956477          0.323792
# 4          5.0         2.0         0.0        8.140316          0.354277
#
#    crowd_score  quant_score
# 0     7.112764        2.625
# 1     7.112764        2.625
# 2     6.762083        2.625
# 3     6.762083        2.625
# 4     6.457229        2.625
#
# [5 rows x 23 columns]

# %%
# Calculate Min and Max for Quantity
quant_min = quant_df.select(min(col("quant_score"))).collect()[0][0]
quant_max = quant_df.select(max(col("quant_score"))).collect()[0][0]

# Perform Normalization
quant_df = quant_df.withColumn("quant_score", 65 * (col("quant_score") - quant_min) / (quant_max - quant_min))

# %%
fig4 = px.histogram(quant_df, x="quant_score", 
                   title="Histogram of Quantity Score (2025)", 
                   labels={
                     "quant_score": "Normalized Quantity Score"
                     })
fig4.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_26.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Source: https://stackoverflow.com/questions/45863360/curried-udf-pyspark
def udf_mult(c):
    def udf_inner(col):
        return udf(
            lambda a, b: a if (b != 0) else 0.0, DoubleType())(c, col)

    return  udf_inner

var_df = quant_df.withColumn("variety_score", 25 * (udf_mult(lit(0.2))(col("art_gallery")) + 
                                            udf_mult(lit(0.1))(col("art_studio")) + 
                                            udf_mult(lit(0.025))(col("auditorium")) + 
                                            udf_mult(lit(0.15))(col("cultural_landmark")) + 
                                            udf_mult(lit(0.05))(col("historical_place")) + 
                                            udf_mult(lit(0.1))(col("monument")) +
                                            udf_mult(lit(0.3))(col("museum")) + 
                                            udf_mult(lit(0.05))(col("performing_arts_theater")) + 
                                            udf_mult(lit(0.025))(col("sculpture"))))

# %%
var_df.limit(5).toPandas()
# Out:
#             station_complex             station Route Borough GTFS Stop ID  \
# 0  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
# 1  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     F      Bk          D42
# 2  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
# 3  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     F      Bk          D42
# 4  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
#
#   Division    CBD  total_ridership             transit_date  \
# 0      BMT  False           2310.0  2025-07-10T00:00:00.000
# 1      BMT  False           2310.0  2025-07-10T00:00:00.000
# 2      BMT  False           2854.0  2025-07-09T00:00:00.000
# 3      BMT  False           2854.0  2025-07-09T00:00:00.000
# 4      BMT  False           3430.0  2025-07-05T00:00:00.000
#
#            str_Coordinates  ...  performing_arts_theater  sculpture  \
# 0  (40.576127, -73.975939)  ...                      5.0        3.0
# 1  (40.576127, -73.975939)  ...                      5.0        3.0
# 2  (40.576127, -73.975939)  ...                      5.0        3.0
# 3  (40.576127, -73.975939)  ...                      5.0        3.0
# 4  (40.576127, -73.975939)  ...                      5.0        3.0
#
#    art_gallery  art_studio  auditorium  log(ridership)  pnorm(ridership)  \
# 0          5.0         2.0         0.0        7.745003          0.288724
# 1          5.0         2.0         0.0        7.745003          0.288724
# 2          5.0         2.0         0.0        7.956477          0.323792
# 3          5.0         2.0         0.0        7.956477          0.323792
# 4          5.0         2.0         0.0        8.140316          0.354277
#
#    crowd_score  quant_score  variety_score
# 0     7.112764      9.32377         24.375
# 1     7.112764      9.32377         24.375
# 2     6.762083      9.32377         24.375
# 3     6.762083      9.32377         24.375
# 4     6.457229      9.32377         24.375
#
# [5 rows x 24 columns]

# %%
fig5 = px.histogram(var_df, x="variety_score", 
                   title="Histogram of Variety Score (2025)", 
                   labels={
                     "variety_score": "Normalized Variety Score"
                     })
fig5.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_29.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
scorecard = var_df.withColumn("avail_score", col("crowd_score") + col("quant_score") + col("variety_score"))

# %%
scorecard.columns
# Out:
# ['station_complex',
#  'station',
#  'Route',
#  'Borough',
#  'GTFS Stop ID',
#  'Division',
#  'CBD',
#  'total_ridership',
#  'transit_date',
#  'str_Coordinates',
#  'cultural_landmark',
#  'historical_place',
#  'monument',
#  'museum',
#  'performing_arts_theater',
#  'sculpture',
#  'art_gallery',
#  'art_studio',
#  'auditorium',
#  'log(ridership)',
#  'pnorm(ridership)',
#  'crowd_score',
#  'quant_score',
#  'variety_score',
#  'avail_score']

# %%
scorecard.limit(5).toPandas()
# Out:
#             station_complex             station Route Borough GTFS Stop ID  \
# 0  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
# 1  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     F      Bk          D42
# 2  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
# 3  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     F      Bk          D42
# 4  W 8 St-NY Aquarium (F,Q)  W 8 St-NY Aquarium     Q      Bk          D42
#
#   Division    CBD  total_ridership             transit_date  \
# 0      BMT  False           2310.0  2025-07-10T00:00:00.000
# 1      BMT  False           2310.0  2025-07-10T00:00:00.000
# 2      BMT  False           2854.0  2025-07-09T00:00:00.000
# 3      BMT  False           2854.0  2025-07-09T00:00:00.000
# 4      BMT  False           3430.0  2025-07-05T00:00:00.000
#
#            str_Coordinates  ...  sculpture  art_gallery  art_studio  \
# 0  (40.576127, -73.975939)  ...        3.0          5.0         2.0
# 1  (40.576127, -73.975939)  ...        3.0          5.0         2.0
# 2  (40.576127, -73.975939)  ...        3.0          5.0         2.0
# 3  (40.576127, -73.975939)  ...        3.0          5.0         2.0
# 4  (40.576127, -73.975939)  ...        3.0          5.0         2.0
#
#    auditorium  log(ridership)  pnorm(ridership)  crowd_score  quant_score  \
# 0         0.0        7.745003          0.288724     7.112764      9.32377
# 1         0.0        7.745003          0.288724     7.112764      9.32377
# 2         0.0        7.956477          0.323792     6.762083      9.32377
# 3         0.0        7.956477          0.323792     6.762083      9.32377
# 4         0.0        8.140316          0.354277     6.457229      9.32377
#
#    variety_score  avail_score
# 0         24.375    40.811534
# 1         24.375    40.811534
# 2         24.375    40.460853
# 3         24.375    40.460853
# 4         24.375    40.156000
#
# [5 rows x 25 columns]

# %%
scorecard.orderBy(col("station_complex")).where(col("station").contains(" St") & col("transit_date").contains("2025-01-07")).limit(5).toPandas()
# Out:
#            station_complex              station Route Borough GTFS Stop ID  \
# 0               103 St (1)               103 St     1       M          119
# 1               103 St (6)               103 St     6       M          624
# 2             103 St (C,B)               103 St     B       M          A18
# 3             103 St (C,B)               103 St     C       M          A18
# 4  103 St-Corona Plaza (7)  103 St-Corona Plaza     7       Q          706
#
#   Division    CBD  total_ridership             transit_date  \
# 0      IRT  False           8693.0  2025-01-07T00:00:00.000
# 1      IRT  False           9483.0  2025-01-07T00:00:00.000
# 2      IND  False           2978.0  2025-01-07T00:00:00.000
# 3      IND  False           2978.0  2025-01-07T00:00:00.000
# 4      IRT  False          18261.0  2025-01-07T00:00:00.000
#
#            str_Coordinates  ...  sculpture  art_gallery  art_studio  \
# 0  (40.799446, -73.968379)  ...       20.0         20.0         8.0
# 1    (40.7906, -73.947478)  ...       13.0         20.0         8.0
# 2  (40.796092, -73.961454)  ...       20.0         20.0        11.0
# 3  (40.796092, -73.961454)  ...       20.0         20.0        11.0
# 4    (40.749865, -73.8627)  ...        6.0          4.0         1.0
#
#    auditorium  log(ridership)  pnorm(ridership)  crowd_score  quant_score  \
# 0        10.0        9.070273          0.508489     4.915110    34.808743
# 1         2.0        9.157256          0.522913     4.770869    34.719945
# 2         8.0        7.999007          0.330844     6.691556    41.379781
# 3         8.0        7.999007          0.330844     6.691556    41.379781
# 4         0.0        9.812523          0.631574     3.684261    11.898907
#
#    variety_score  avail_score
# 0         25.000    64.723853
# 1         25.000    64.490815
# 2         25.000    73.071338
# 3         25.000    73.071338
# 4         24.375    39.958168
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Get stations and lines with best scores

# %%
from pyspark.sql.functions import desc, mean, median, asc
scores = scorecard.dropDuplicates(["station_complex"]).groupBy("station_complex", "str_Coordinates").agg(median('avail_score')).orderBy(desc(col("median(avail_score)")))
scores_by_line = scorecard.groupBy("Route").agg(median('avail_score')).orderBy(desc(col("median(avail_score)")))

# %%
scores.limit(10).toPandas()
# Out:
#                   station_complex          str_Coordinates  \
# 0                    Astor Pl (6)   (40.730054, -73.99107)
# 1                  8 St-NYU (R,W)  (40.730328, -73.992629)
# 2                       18 St (1)   (40.74104, -73.997871)
# 3                    Canal St (1)  (40.722854, -74.006277)
# 4                 Prince St (R,W)  (40.724329, -73.997702)
# 5  W 4 St-Wash Sq (A,C,E,B,D,F,M)  (40.732338, -74.000495)
# 6                       23 St (1)  (40.744081, -73.995657)
# 7                 Spring St (C,E)  (40.726227, -74.003739)
# 8                  Houston St (1)  (40.728251, -74.005367)
# 9                   Spring St (6)  (40.722301, -73.997141)
#
#    median(avail_score)
# 0            93.662400
# 1            93.591716
# 2            93.365472
# 3            93.013861
# 4            93.002626
# 5            92.585082
# 6            92.377252
# 7            92.349997
# 8            92.344062
# 9            92.161327

# %%
scores_by_line.limit(5).toPandas()
# Out:
#   Route  median(avail_score)
# 0     W            87.085960
# 1     1            83.435366
# 2     E            73.958519
# 3     C            72.719707
# 4     B            71.386228

# %% [markdown]
# ## Get stations and lines with worst scores

# %%
scorecard.dropDuplicates(["station_complex"]).groupBy("station_complex", "str_Coordinates").agg(median('avail_score')).orderBy(asc(col("median(avail_score)"))).limit(10).toPandas()
# Out:
#                 station_complex          str_Coordinates  median(avail_score)
# 0  Howard Beach-JFK Airport (A)  (40.660476, -73.830301)             6.596865
# 1               Beach 67 St (A)  (40.590927, -73.796924)            10.099821
# 2               Beach 60 St (A)  (40.592374, -73.788522)            10.657567
# 3               Beach 36 St (A)  (40.595398, -73.768175)            11.159734
# 4               Beach 44 St (A)  (40.592943, -73.776013)            11.811981
# 5      Far Rockaway-Mott Av (A)  (40.603995, -73.755405)            12.449973
# 6               Beach 25 St (A)  (40.600066, -73.761353)            12.953129
# 7               New Lots Av (3)  (40.666235, -73.884079)            13.583838
# 8             Gun Hill Rd (2,5)  (40.869526, -73.846384)            13.986416
# 9               Gun Hill Rd (5)  (40.869526, -73.846384)            14.597133

# %%
scorecard.groupBy("Route").agg(median('avail_score')).orderBy(asc(col("median(avail_score)"))).limit(5).toPandas()
# Out:
#   Route  median(avail_score)
# 0     5            36.070984
# 1     A            37.865473
# 2     Z            39.663769
# 3     J            39.789277
# 4     D            40.261197

# %%
scores_by_line.limit(10).toPandas()
# Out:
#   Route  median(avail_score)
# 0     W            87.085960
# 1     1            83.435366
# 2     E            73.958519
# 3     C            72.719707
# 4     B            71.386228
# 5     3            70.324347
# 6     S            66.883624
# 7     G            65.631475
# 8     R            62.870059
# 9     M            57.543413

# %%
# Save data
# scores.write.csv('Score_Results',header=True)
# scores_by_line.write.csv('Score_by_Line', header=True)

# %%
fig6 = px.histogram(scores, x="median(avail_score)", 
                   title="Histogram of Creative Availbility Score by Station (2025)", 
                   labels={
                     "median(avail_score)": "Creative Availability Score (0-100)"
                     })
fig6.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_41.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
fig7 = px.histogram(scores_by_line, x="median(avail_score)", 
                   title="Histogram of Creative Availbility Score by Subway Line (2025)", 
                   labels={
                     "median(avail_score)": "Creative Availability Score (0-100)"
                     }, nbins=25)
fig7.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_42.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# # Plotting NYC Subway Lines

# %%
# !pip install pipwin
# Out:
# Requirement already satisfied: pipwin in /opt/conda/lib/python3.11/site-packages (0.5.2)
# Requirement already satisfied: docopt in /opt/conda/lib/python3.11/site-packages (from pipwin) (0.6.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from pipwin) (2.31.0)
# Requirement already satisfied: pyprind in /opt/conda/lib/python3.11/site-packages (from pipwin) (2.11.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from pipwin) (1.16.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in /opt/conda/lib/python3.11/site-packages (from pipwin) (4.12.2)
# Requirement already satisfied: js2py in /opt/conda/lib/python3.11/site-packages (from pipwin) (0.74)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from pipwin) (23.2)
# Requirement already satisfied: pySmartDL>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from pipwin) (1.3.4)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4>=4.9.0->pipwin) (2.5)
# Requirement already satisfied: tzlocal>=1.2 in /opt/conda/lib/python3.11/site-packages (from js2py->pipwin) (5.3.1)
# Requirement already satisfied: pyjsparser>=2.5.1 in /opt/conda/lib/python3.11/site-packages (from js2py->pipwin) (2.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->pipwin) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->pipwin) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->pipwin) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->pipwin) (2025.7.14)

# %%
# !pip install descartes
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import descartes
# Out:
# Requirement already satisfied: descartes in /opt/conda/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (from descartes) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->descartes) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib->descartes) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->descartes) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->descartes) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /opt/conda/lib/python3.11/site-packages (from matplotlib->descartes) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->descartes) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->descartes) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->descartes) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib->descartes) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->descartes) (1.16.0)

# %%
from pyspark.sql import Row

# Dummy dataframe for GeoJSON
df = spark.createDataFrame([
    Row(borough="Manhattan", b=1),
    Row(borough="Bronx", b=2),
    Row(borough="Brookyln", b=3),
    Row(borough="Queens", b=4),
    Row(borough="Staten Island", b=5),
])

# %%
import json
import plotly.graph_objects as go
from collections import defaultdict

# Load NYC GeoJSON file from GitHub: https://github.com/nycehs/NYC_geography/blob/master/borough.geo.json
with open("Final_Data/borough.geo.json") as f:
    boroughs_geojson = json.load(f)

borough_names = [f["properties"]["BoroName"] for f in boroughs_geojson["features"]]
color_values = [1, 2, 3, 4, 5]  # dummy values

# Create base figure with boroughs
fig = go.Figure()

fig.add_trace(go.Choropleth(
    geojson=boroughs_geojson,
    locations=borough_names,
    z=color_values,
    featureidkey="properties.BoroName",
    colorscale=["lightgray", "darkgray"],
    marker_line_width=0.5,
    marker_line_color="white",
    showscale=False
))

# Update locations and layout
fig.update_geos(
    fitbounds="locations",
    visible=False
)

fig.update_layout(
    height=700,
    margin={"r":0,"t":0,"l":0,"b":0}
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="720"
#     src="iframe_figures/figure_46.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Load subway station GeoJSON from data.ny.gov and colors
# Source: https://data.ny.gov/Transportation/MTA-Subway-Stations/39hk-dx4f/about_data
# Export as GeoJSON
with open("Final_Data/MTA Subway Stations_20250806.geo.json") as f:
    stations_geojson = json.load(f)

# MTA official colors
mta_colors = {
    "E": "#0039A6",
    "B": "#FF6319", 
    "W": "#FCCC0A",
}

# %%
stations_geojson["features"]
# Out:
# [{'type': 'Feature',
#   'properties': {'station_id': '1',
#    'north_direction_label': 'Last Stop',
#    'line': 'Astoria',
#    'daytime_routes': 'N W',
#    'complex_id': '1',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R01',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': 'Astoria-Ditmars Blvd',
#    'gtfs_longitude': '-73.912034',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Manhattan',
#    'cbd': 'False',
#    'borough': 'Q',
#    'gtfs_latitude': '40.775036'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.912034, 40.775036]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '2',
#    'north_direction_label': 'Astoria',
#    'line': 'Astoria',
#    'daytime_routes': 'N W',
#    'complex_id': '2',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'R03',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': 'Astoria Blvd',
#    'gtfs_longitude': '-73.917843',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Manhattan',
#    'cbd': 'False',
#    'borough': 'Q',
#    'gtfs_latitude': '40.770258'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.917843, 40.770258]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '3',
#    'north_direction_label': 'Astoria',
#    'line': 'Astoria',
#    'daytime_routes': 'N W',
#    'complex_id': '3',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R04',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '30 Av',
#    'gtfs_longitude': '-73.921479',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Manhattan',
#    'cbd': 'False',
#    'borough': 'Q',
#    'gtfs_latitude': '40.766779'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.921479, 40.766779]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '4',
#    'north_direction_label': 'Astoria',
#    'line': 'Astoria',
#    'daytime_routes': 'N W',
#    'complex_id': '4',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R05',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': 'Broadway',
#    'gtfs_longitude': '-73.925508',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Manhattan',
#    'cbd': 'False',
#    'borough': 'Q',
#    'gtfs_latitude': '40.76182'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.925508, 40.76182]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '5',
#    'north_direction_label': 'Astoria',
#    'line': 'Astoria',
#    'daytime_routes': 'N W',
#    'complex_id': '5',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R06',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '36 Av',
#    'gtfs_longitude': '-73.929575',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Manhattan',
#    'cbd': 'False',
#    'borough': 'Q',
#    'gtfs_latitude': '40.756804'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.929575, 40.756804]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '6',
#    'north_direction_label': 'Astoria',
#    'line': 'Astoria',
#    'daytime_routes': 'N W',
#    'complex_id': '6',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R08',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '39 Av-Dutch Kills',
#    'gtfs_longitude': '-73.932755',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Manhattan',
#    'cbd': 'False',
#    'borough': 'Q',
#    'gtfs_latitude': '40.752882'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.932755, 40.752882]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '7',
#    'north_direction_label': 'Queens',
#    'line': 'Astoria',
#    'daytime_routes': 'N R W',
#    'complex_id': '613',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R11',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Lexington Av/59 St',
#    'gtfs_longitude': '-73.967258',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.76266'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.967258, 40.76266]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '8',
#    'north_direction_label': 'Queens',
#    'line': 'Astoria',
#    'daytime_routes': 'N R W',
#    'complex_id': '8',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R13',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '5 Av/59 St',
#    'gtfs_longitude': '-73.973347',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.764811'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.973347, 40.764811]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '9',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'N Q R W',
#    'complex_id': '9',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'R14',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '57 St-7 Av',
#    'gtfs_longitude': '-73.980658',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.764664'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.980658, 40.764664]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '10',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'N R W',
#    'complex_id': '10',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R15',
#    'structure': 'Subway',
#    'ada_notes': 'Uptown only',
#    'stop_name': '49 St',
#    'gtfs_longitude': '-73.984139',
#    'ada_northbound': '1',
#    'ada': '2',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.759901'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.984139, 40.759901]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '11',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'N Q R W',
#    'complex_id': '611',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'R16',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Times Sq-42 St',
#    'gtfs_longitude': '-73.986754',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.754672'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.986754, 40.754672]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '12',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'N Q R W',
#    'complex_id': '607',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'R17',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '34 St-Herald Sq',
#    'gtfs_longitude': '-73.98795',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.749567'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.98795, 40.749567]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '13',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'R W',
#    'complex_id': '13',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R18',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '28 St',
#    'gtfs_longitude': '-73.988691',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.745494'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.988691, 40.745494]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '14',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'R W',
#    'complex_id': '14',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R19',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '23 St',
#    'gtfs_longitude': '-73.989344',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.741303'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.989344, 40.741303]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '15',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'N Q R W',
#    'complex_id': '602',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'R20',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '14 St-Union Sq',
#    'gtfs_longitude': '-73.990568',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.735736'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.990568, 40.735736]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '16',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'R W',
#    'complex_id': '16',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R21',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '8 St-NYU',
#    'gtfs_longitude': '-73.992629',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.730328'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.992629, 40.730328]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '17',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'R W',
#    'complex_id': '17',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R22',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Prince St',
#    'gtfs_longitude': '-73.997702',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.724329'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.997702, 40.724329]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '18',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway',
#    'daytime_routes': 'R W',
#    'complex_id': '623',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R23',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Canal St',
#    'gtfs_longitude': '-74.001775',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.719527'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.001775, 40.719527]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '19',
#    'north_direction_label': 'Uptown',
#    'line': 'Manhattan Bridge',
#    'daytime_routes': 'N Q',
#    'complex_id': '623',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'Q01',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Canal St',
#    'gtfs_longitude': '-74.00046',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.718383'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.00046, 40.718383]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '20',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway',
#    'daytime_routes': 'R W',
#    'complex_id': '20',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R24',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'City Hall',
#    'gtfs_longitude': '-74.006978',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.713282'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.006978, 40.713282]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '21',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway',
#    'daytime_routes': 'R W',
#    'complex_id': '624',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'R25',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Cortlandt St',
#    'gtfs_longitude': '-74.011029',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.710668'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.011029, 40.710668]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '22',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway',
#    'daytime_routes': 'R W',
#    'complex_id': '22',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R26',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Rector St',
#    'gtfs_longitude': '-74.013342',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.70722'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.013342, 40.70722]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '23',
#    'north_direction_label': 'Uptown',
#    'line': 'Broadway',
#    'daytime_routes': 'R W',
#    'complex_id': '635',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R27',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Whitehall St-South Ferry',
#    'gtfs_longitude': '-74.012994',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Downtown',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.703087'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.012994, 40.703087]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '24',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway',
#    'daytime_routes': 'R',
#    'complex_id': '620',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R28',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Court St',
#    'gtfs_longitude': '-73.991777',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.6941'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.991777, 40.6941]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '25',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway',
#    'daytime_routes': 'R',
#    'complex_id': '636',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'R29',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Jay St-MetroTech',
#    'gtfs_longitude': '-73.985942',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.69218'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.985942, 40.69218]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '26',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'B Q R',
#    'complex_id': '26',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'R30',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'DeKalb Av',
#    'gtfs_longitude': '-73.981824',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.690635'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.981824, 40.690635]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '27',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'D N R',
#    'complex_id': '617',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'R31',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Atlantic Av-Barclays Ctr',
#    'gtfs_longitude': '-73.97881',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.683666'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.97881, 40.683666]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '28',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'R',
#    'complex_id': '28',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R32',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Union St',
#    'gtfs_longitude': '-73.98311',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.677316'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.98311, 40.677316]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '29',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'R',
#    'complex_id': '608',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R33',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '4 Av-9 St',
#    'gtfs_longitude': '-73.988302',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.670847'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.988302, 40.670847]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '30',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'R',
#    'complex_id': '30',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R34',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Prospect Av',
#    'gtfs_longitude': '-73.992872',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.665414'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.992872, 40.665414]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '31',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'R',
#    'complex_id': '31',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R35',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '25 St',
#    'gtfs_longitude': '-73.998091',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.660397'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.998091, 40.660397]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '32',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'D N R',
#    'complex_id': '32',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R36',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '36 St',
#    'gtfs_longitude': '-74.003549',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.655144'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.003549, 40.655144]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '33',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'R',
#    'complex_id': '33',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R39',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '45 St',
#    'gtfs_longitude': '-74.010006',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.648939'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.010006, 40.648939]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '34',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'R',
#    'complex_id': '34',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R40',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '53 St',
#    'gtfs_longitude': '-74.014034',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.645069'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.014034, 40.645069]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '35',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'N R',
#    'complex_id': '35',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'R41',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '59 St',
#    'gtfs_longitude': '-74.017881',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.641362'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.017881, 40.641362]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '36',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'R',
#    'complex_id': '36',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R42',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Bay Ridge Av',
#    'gtfs_longitude': '-74.023377',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Bay Ridge',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.634967'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.023377, 40.634967]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '37',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'R',
#    'complex_id': '37',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R43',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '77 St',
#    'gtfs_longitude': '-74.02551',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Bay Ridge',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.629742'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.02551, 40.629742]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '38',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'R',
#    'complex_id': '38',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'R44',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '86 St',
#    'gtfs_longitude': '-74.028398',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Bay Ridge',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.622687'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.028398, 40.622687]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '39',
#    'north_direction_label': 'Manhattan',
#    'line': '4th Av',
#    'daytime_routes': 'R',
#    'complex_id': '39',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'R45',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Bay Ridge-95 St',
#    'gtfs_longitude': '-74.030876',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Last Stop',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.616622'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.030876, 40.616622]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '40',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'B Q',
#    'complex_id': '617',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'D24',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Atlantic Av-Barclays Ctr',
#    'gtfs_longitude': '-73.97689',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.68446'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.97689, 40.68446]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '41',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'B Q',
#    'complex_id': '41',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D25',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '7 Av',
#    'gtfs_longitude': '-73.972367',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.67705'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.972367, 40.67705]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '42',
#    'north_direction_label': 'Northbound',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'B Q S',
#    'complex_id': '42',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'D26',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Prospect Park',
#    'gtfs_longitude': '-73.962246',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.661614'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.962246, 40.661614]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '43',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'Q',
#    'complex_id': '43',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D27',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Parkside Av',
#    'gtfs_longitude': '-73.961495',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.655292'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.961495, 40.655292]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '44',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'B Q',
#    'complex_id': '44',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D28',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Church Av',
#    'gtfs_longitude': '-73.962982',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.650527'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.962982, 40.650527]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '45',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'Q',
#    'complex_id': '45',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D29',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Beverley Rd',
#    'gtfs_longitude': '-73.964492',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.644031'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.964492, 40.644031]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '46',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'Q',
#    'complex_id': '46',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D30',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Cortelyou Rd',
#    'gtfs_longitude': '-73.963891',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.640927'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.963891, 40.640927]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '47',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'B Q',
#    'complex_id': '47',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D31',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Newkirk Plaza',
#    'gtfs_longitude': '-73.962793',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.635082'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.962793, 40.635082]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '48',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'Q',
#    'complex_id': '48',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'D32',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Avenue H',
#    'gtfs_longitude': '-73.961639',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.62927'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.961639, 40.62927]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '49',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'Q',
#    'complex_id': '49',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D33',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Avenue J',
#    'gtfs_longitude': '-73.960803',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.625039'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.960803, 40.625039]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '50',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'Q',
#    'complex_id': '50',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D34',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Avenue M',
#    'gtfs_longitude': '-73.959399',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.617618'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.959399, 40.617618]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '51',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'B Q',
#    'complex_id': '51',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'D35',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Kings Hwy',
#    'gtfs_longitude': '-73.957734',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.60867'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.957734, 40.60867]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '52',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'Q',
#    'complex_id': '52',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D37',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Avenue U',
#    'gtfs_longitude': '-73.955929',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.5993'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.955929, 40.5993]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '53',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'Q',
#    'complex_id': '53',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D38',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Neck Rd',
#    'gtfs_longitude': '-73.955161',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.595246'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.955161, 40.595246]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '54',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'B Q',
#    'complex_id': '54',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D39',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Sheepshead Bay',
#    'gtfs_longitude': '-73.954155',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.586896'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.954155, 40.586896]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '55',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'B Q',
#    'complex_id': '55',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D40',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': 'Brighton Beach',
#    'gtfs_longitude': '-73.961376',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.577621'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.961376, 40.577621]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '56',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'Q',
#    'complex_id': '56',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D41',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': 'Ocean Pkwy',
#    'gtfs_longitude': '-73.968501',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.576312'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.968501, 40.576312]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '57',
#    'north_direction_label': 'Manhattan',
#    'line': 'Broadway - Brighton',
#    'daytime_routes': 'F Q',
#    'complex_id': '57',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'D42',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': 'W 8 St-NY Aquarium',
#    'gtfs_longitude': '-73.975939',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.576127'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.975939, 40.576127]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '58',
#    'north_direction_label': 'Manhattan',
#    'line': 'Sea Beach / West End / Culver / Brighton',
#    'daytime_routes': 'D F N Q',
#    'complex_id': '58',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'D43',
#    'structure': 'Viaduct',
#    'ada_notes': None,
#    'stop_name': 'Coney Island-Stillwell Av',
#    'gtfs_longitude': '-73.981233',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Last Stop',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.577422'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.981233, 40.577422]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '59',
#    'north_direction_label': 'Manhattan',
#    'line': 'West End',
#    'daytime_routes': 'D',
#    'complex_id': '59',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'B12',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': '9 Av',
#    'gtfs_longitude': '-73.994324',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.646292'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.994324, 40.646292]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '60',
#    'north_direction_label': 'Manhattan',
#    'line': 'West End',
#    'daytime_routes': 'D',
#    'complex_id': '60',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'B13',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': 'Fort Hamilton Pkwy',
#    'gtfs_longitude': '-73.994304',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.640914'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.994304, 40.640914]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '61',
#    'north_direction_label': 'Manhattan',
#    'line': 'West End',
#    'daytime_routes': 'D',
#    'complex_id': '61',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'B14',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '50 St',
#    'gtfs_longitude': '-73.994791',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.63626'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.994791, 40.63626]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '62',
#    'north_direction_label': 'Manhattan',
#    'line': 'West End',
#    'daytime_routes': 'D',
#    'complex_id': '62',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'B15',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '55 St',
#    'gtfs_longitude': '-73.995476',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.631435'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.995476, 40.631435]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '63',
#    'north_direction_label': 'Manhattan',
#    'line': 'West End',
#    'daytime_routes': 'D',
#    'complex_id': '615',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'B16',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '62 St',
#    'gtfs_longitude': '-73.996895',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.626472'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.996895, 40.626472]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '64',
#    'north_direction_label': 'Manhattan',
#    'line': 'West End',
#    'daytime_routes': 'D',
#    'complex_id': '64',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'B17',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '71 St',
#    'gtfs_longitude': '-73.998864',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.619589'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.998864, 40.619589]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '65',
#    'north_direction_label': 'Manhattan',
#    'line': 'West End',
#    'daytime_routes': 'D',
#    'complex_id': '65',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'B18',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '79 St',
#    'gtfs_longitude': '-74.00061',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.613501'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.00061, 40.613501]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '66',
#    'north_direction_label': 'Manhattan',
#    'line': 'West End',
#    'daytime_routes': 'D',
#    'complex_id': '66',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'B19',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '18 Av',
#    'gtfs_longitude': '-74.001736',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.607954'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.001736, 40.607954]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '67',
#    'north_direction_label': 'Manhattan',
#    'line': 'West End',
#    'daytime_routes': 'D',
#    'complex_id': '67',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'B20',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '20 Av',
#    'gtfs_longitude': '-73.998168',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.604556'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.998168, 40.604556]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '68',
#    'north_direction_label': 'Manhattan',
#    'line': 'West End',
#    'daytime_routes': 'D',
#    'complex_id': '68',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'B21',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': 'Bay Pkwy',
#    'gtfs_longitude': '-73.993728',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Southbound',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.601875'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.993728, 40.601875]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '69',
#    'north_direction_label': 'Manhattan',
#    'line': 'West End',
#    'daytime_routes': 'D',
#    'complex_id': '69',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'B22',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '25 Av',
#    'gtfs_longitude': '-73.986829',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.597704'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.986829, 40.597704]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '70',
#    'north_direction_label': 'Manhattan',
#    'line': 'West End',
#    'daytime_routes': 'D',
#    'complex_id': '70',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'B23',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': 'Bay 50 St',
#    'gtfs_longitude': '-73.983765',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.588841'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.983765, 40.588841]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '71',
#    'north_direction_label': 'Manhattan',
#    'line': 'Sea Beach',
#    'daytime_routes': 'N',
#    'complex_id': '71',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'N02',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': '8 Av',
#    'gtfs_longitude': '-74.011719',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.635064'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.011719, 40.635064]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '72',
#    'north_direction_label': 'Manhattan',
#    'line': 'Sea Beach',
#    'daytime_routes': 'N',
#    'complex_id': '72',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'N03',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Fort Hamilton Pkwy',
#    'gtfs_longitude': '-74.005351',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.631386'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.005351, 40.631386]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '73',
#    'north_direction_label': 'Manhattan',
#    'line': 'Sea Beach',
#    'daytime_routes': 'N',
#    'complex_id': '615',
#    'division': 'BMT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'N04',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'New Utrecht Av',
#    'gtfs_longitude': '-73.996353',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.624842'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.996353, 40.624842]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '74',
#    'north_direction_label': 'Manhattan',
#    'line': 'Sea Beach',
#    'daytime_routes': 'N',
#    'complex_id': '74',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'N05',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': '18 Av',
#    'gtfs_longitude': '-73.990414',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.620671'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.990414, 40.620671]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '75',
#    'north_direction_label': 'Manhattan',
#    'line': 'Sea Beach',
#    'daytime_routes': 'N',
#    'complex_id': '75',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'N06',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': '20 Av',
#    'gtfs_longitude': '-73.985026',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.61741'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.985026, 40.61741]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '76',
#    'north_direction_label': 'Manhattan',
#    'line': 'Sea Beach',
#    'daytime_routes': 'N',
#    'complex_id': '76',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'N07',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Bay Pkwy',
#    'gtfs_longitude': '-73.981848',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.611815'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.981848, 40.611815]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '77',
#    'north_direction_label': 'Manhattan',
#    'line': 'Sea Beach',
#    'daytime_routes': 'N',
#    'complex_id': '77',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'N08',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Kings Hwy',
#    'gtfs_longitude': '-73.980353',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.603923'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.980353, 40.603923]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '78',
#    'north_direction_label': 'Manhattan',
#    'line': 'Sea Beach',
#    'daytime_routes': 'N',
#    'complex_id': '78',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'N09',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Avenue U',
#    'gtfs_longitude': '-73.979137',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.597473'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.979137, 40.597473]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '79',
#    'north_direction_label': 'Manhattan',
#    'line': 'Sea Beach',
#    'daytime_routes': 'N',
#    'complex_id': '79',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'N10',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': '86 St',
#    'gtfs_longitude': '-73.97823',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Coney Island',
#    'cbd': 'False',
#    'borough': 'Bk',
#    'gtfs_latitude': '40.592721'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.97823, 40.592721]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '80',
#    'north_direction_label': 'Jamaica',
#    'line': 'Jamaica',
#    'daytime_routes': 'J Z',
#    'complex_id': '80',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'J12',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '121 St',
#    'gtfs_longitude': '-73.828294',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Manhattan',
#    'cbd': 'False',
#    'borough': 'Q',
#    'gtfs_latitude': '40.700492'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.828294, 40.700492]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '81',
#    'north_direction_label': 'Jamaica',
#    'line': 'Jamaica',
#    'daytime_routes': 'J',
#    'complex_id': '81',
#    'division': 'BMT',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'J13',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': '111 St',
#    'gtfs_longitude': '-73.836345',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Manhattan',
#    'cbd': 'False',
#    'borough': 'Q',
#    'gtfs_latitude': '40.697418'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.836345, 40.697418]}},
#  {'type': 'Feature',
# ...
#    'line': 'Lexington - Shuttle',
#    'daytime_routes': 'S',
#    'complex_id': '611',
#    'division': 'IRT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': '902',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Times Sq-42 St',
#    'gtfs_longitude': '-73.986229',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Grand Central',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.755983'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.986229, 40.755983]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '469',
#    'north_direction_label': 'Times Square',
#    'line': 'Lexington - Shuttle',
#    'daytime_routes': 'S',
#    'complex_id': '610',
#    'division': 'IRT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': '901',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': 'Grand Central-42 St',
#    'gtfs_longitude': '-73.979189',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Last Stop',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.752769'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.979189, 40.752769]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '471',
#    'north_direction_label': 'Last Stop',
#    'line': 'Flushing',
#    'daytime_routes': '7',
#    'complex_id': '471',
#    'division': 'IRT',
#    'ada_southbound': '1',
#    'gtfs_stop_id': '726',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '34 St-Hudson Yards',
#    'gtfs_longitude': '-74.00191',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Queens',
#    'cbd': 'True',
#    'borough': 'M',
#    'gtfs_latitude': '40.755882'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.00191, 40.755882]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '475',
#    'north_direction_label': 'Last Stop',
#    'line': 'Second Av',
#    'daytime_routes': 'Q',
#    'complex_id': '475',
#    'division': 'IND',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'Q05',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '96 St',
#    'gtfs_longitude': '-73.947152',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Downtown',
#    'cbd': 'False',
#    'borough': 'M',
#    'gtfs_latitude': '40.784318'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.947152, 40.784318]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '476',
#    'north_direction_label': 'Uptown',
#    'line': 'Second Av',
#    'daytime_routes': 'Q',
#    'complex_id': '476',
#    'division': 'IND',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'Q04',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '86 St',
#    'gtfs_longitude': '-73.951787',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Downtown',
#    'cbd': 'False',
#    'borough': 'M',
#    'gtfs_latitude': '40.777891'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.951787, 40.777891]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '477',
#    'north_direction_label': 'Uptown',
#    'line': 'Second Av',
#    'daytime_routes': 'Q',
#    'complex_id': '477',
#    'division': 'IND',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'Q03',
#    'structure': 'Subway',
#    'ada_notes': None,
#    'stop_name': '72 St',
#    'gtfs_longitude': '-73.958424',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Downtown',
#    'cbd': 'False',
#    'borough': 'M',
#    'gtfs_latitude': '40.768799'},
#   'geometry': {'type': 'Point', 'coordinates': [-73.958424, 40.768799]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '501',
#    'north_direction_label': 'Last Stop',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '501',
#    'division': 'SIR',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'S31',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'St George',
#    'gtfs_longitude': '-74.073643',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.643748'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.073643, 40.643748]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '502',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '502',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S30',
#    'structure': 'At Grade',
#    'ada_notes': None,
#    'stop_name': 'Tompkinsville',
#    'gtfs_longitude': '-74.074835',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.636949'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.074835, 40.636949]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '503',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '503',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S29',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': 'Stapleton',
#    'gtfs_longitude': '-74.075162',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.627915'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.075162, 40.627915]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '504',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '504',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S28',
#    'structure': 'Elevated',
#    'ada_notes': None,
#    'stop_name': 'Clifton',
#    'gtfs_longitude': '-74.071402',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.621319'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.071402, 40.621319]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '505',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '505',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S27',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Grasmere',
#    'gtfs_longitude': '-74.084087',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.603117'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.084087, 40.603117]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '506',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '506',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S26',
#    'structure': 'Embankment',
#    'ada_notes': None,
#    'stop_name': 'Old Town',
#    'gtfs_longitude': '-74.087368',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.596612'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.087368, 40.596612]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '507',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '507',
#    'division': 'SIR',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'S25',
#    'structure': 'Embankment',
#    'ada_notes': None,
#    'stop_name': 'Dongan Hills',
#    'gtfs_longitude': '-74.09609',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.588849'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.09609, 40.588849]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '508',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '508',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S24',
#    'structure': 'Embankment',
#    'ada_notes': None,
#    'stop_name': 'Jefferson Av',
#    'gtfs_longitude': '-74.103338',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.583591'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.103338, 40.583591]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '509',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '509',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S23',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Grant City',
#    'gtfs_longitude': '-74.109704',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.578965'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.109704, 40.578965]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '510',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '510',
#    'division': 'SIR',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'S22',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'New Dorp',
#    'gtfs_longitude': '-74.11721',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.57348'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.11721, 40.57348]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '511',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '511',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S21',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Oakwood Heights',
#    'gtfs_longitude': '-74.12632',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.56511'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.12632, 40.56511]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '512',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '512',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S20',
#    'structure': 'Embankment',
#    'ada_notes': None,
#    'stop_name': 'Bay Terrace',
#    'gtfs_longitude': '-74.136907',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.5564'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.136907, 40.5564]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '513',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '513',
#    'division': 'SIR',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'S19',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Great Kills',
#    'gtfs_longitude': '-74.151399',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.551231'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.151399, 40.551231]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '514',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '514',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S18',
#    'structure': 'Embankment',
#    'ada_notes': None,
#    'stop_name': 'Eltingville',
#    'gtfs_longitude': '-74.16457',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.544601'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.16457, 40.544601]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '515',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '515',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S17',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Annadale',
#    'gtfs_longitude': '-74.178217',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.54046'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.178217, 40.54046]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '516',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '516',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S16',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Huguenot',
#    'gtfs_longitude': '-74.191794',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.533674'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.191794, 40.533674]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '517',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '517',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S15',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': "Prince's Bay",
#    'gtfs_longitude': '-74.200064',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.525507'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.200064, 40.525507]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '518',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '518',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S14',
#    'structure': 'Embankment',
#    'ada_notes': None,
#    'stop_name': 'Pleasant Plains',
#    'gtfs_longitude': '-74.217847',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'South Shore',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.52241'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.217847, 40.52241]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '519',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '519',
#    'division': 'SIR',
#    'ada_southbound': '0',
#    'gtfs_stop_id': 'S13',
#    'structure': 'Open Cut',
#    'ada_notes': None,
#    'stop_name': 'Richmond Valley',
#    'gtfs_longitude': '-74.229141',
#    'ada_northbound': '0',
#    'ada': '0',
#    'south_direction_label': 'Tottenville',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.519631'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.229141, 40.519631]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '522',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '522',
#    'division': 'SIR',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'S09',
#    'structure': 'At Grade',
#    'ada_notes': None,
#    'stop_name': 'Tottenville',
#    'gtfs_longitude': '-74.251961',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Last Stop',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.512764'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.251961, 40.512764]}},
#  {'type': 'Feature',
#   'properties': {'station_id': '523',
#    'north_direction_label': 'Ferry',
#    'line': 'Staten Island',
#    'daytime_routes': 'SIR',
#    'complex_id': '523',
#    'division': 'SIR',
#    'ada_southbound': '1',
#    'gtfs_stop_id': 'S11',
#    'structure': 'At Grade',
#    'ada_notes': None,
#    'stop_name': 'Arthur Kill',
#    'gtfs_longitude': '-74.242096',
#    'ada_northbound': '1',
#    'ada': '1',
#    'south_direction_label': 'Tottenville',
#    'cbd': 'False',
#    'borough': 'SI',
#    'gtfs_latitude': '40.516578'},
#   'geometry': {'type': 'Point', 'coordinates': [-74.242096, 40.516578]}}]

# %% [markdown]
# ## Get scores from `scores` DataFrame

# %%
# UDF to split station name and routes
def get_station(name):
    return name.split("(")[0].strip()

udf_get_station = udf(get_station)

scores = scorecard.groupBy("station_complex", "str_Coordinates", "Route").agg(median('avail_score')).orderBy(desc(col("median(avail_score)")))
scores = scores.withColumn("stop_name", udf_get_station(col("station_complex")))

# %%
scores.limit(10).toPandas()
# Out:
#                   station_complex          str_Coordinates Route  \
# 0                  8 St-NYU (R,W)  (40.730328, -73.992629)     R
# 1                  8 St-NYU (R,W)  (40.730328, -73.992629)     W
# 2                    Astor Pl (6)   (40.730054, -73.99107)     6
# 3                       18 St (1)   (40.74104, -73.997871)     1
# 4                    Canal St (1)  (40.722854, -74.006277)     1
# 5                 Prince St (R,W)  (40.724329, -73.997702)     R
# 6                 Prince St (R,W)  (40.724329, -73.997702)     W
# 7  W 4 St-Wash Sq (A,C,E,B,D,F,M)  (40.732338, -74.000495)     A
# 8  W 4 St-Wash Sq (A,C,E,B,D,F,M)  (40.732338, -74.000495)     B
# 9  W 4 St-Wash Sq (A,C,E,B,D,F,M)  (40.732338, -74.000495)     C
#
#    median(avail_score)       stop_name
# 0            93.699621        8 St-NYU
# 1            93.699621        8 St-NYU
# 2            93.663846        Astor Pl
# 3            93.327617           18 St
# 4            93.201805        Canal St
# 5            93.155470       Prince St
# 6            93.155470       Prince St
# 7            92.679114  W 4 St-Wash Sq
# 8            92.679114  W 4 St-Wash Sq
# 9            92.679114  W 4 St-Wash Sq

# %%
# Get score based on stop name and route
scores.filter( (col("stop_name").contains("Lexington"))).select("*").show()
# Out:
# +--------------------+--------------------+-----+-------------------+------------------+
# |     station_complex|     str_Coordinates|Route|median(avail_score)|         stop_name|
# +--------------------+--------------------+-----+-------------------+------------------+
# |Lexington Av/63 S...|(40.764629, -73.9...|    F|  89.13723280700466|Lexington Av/63 St|
# |Lexington Av/63 S...|(40.764629, -73.9...|    Q|  89.13723280700466|Lexington Av/63 St|
# +--------------------+--------------------+-----+-------------------+------------------+

# %%
# Group stations by line
line_stations = {}
for feature in stations_geojson["features"]:
    coords = feature["geometry"]["coordinates"]  # [lon, lat]
    props = feature["properties"]
    routes = props["daytime_routes"].split()

    for route in routes:
        if route in mta_colors.keys():
            lon, lat = coords[0], coords[1]
            stop_name = props["stop_name"]
            size = 1
            try: 
                size = scores.filter( (col("stop_name") == stop_name) & (col("Route") == route)).select(col("median(avail_score)")).first()["median(avail_score)"]            
                size = size / 10.0
            except:
                size = 1
            val = (lon, lat, stop_name, size)

            print(val) # Debug statement
            if route in line_stations.keys():
                line_stations[route].append(val)
            else:
                line_stations[route] = [val]
# Out:
# (-73.912034, 40.775036, 'Astoria-Ditmars Blvd', 3.811295073782773)
# (-73.917843, 40.770258, 'Astoria Blvd', 4.308446487582657)
# (-73.921479, 40.766779, '30 Av', 4.547316187242545)
# (-73.925508, 40.76182, 'Broadway', 5.041404864864728)
# (-73.929575, 40.756804, '36 Av', 5.880039980794761)
# (-73.932755, 40.752882, '39 Av-Dutch Kills', 6.5142092807510865)
# (-73.967258, 40.76266, 'Lexington Av/59 St', 1)
# (-73.973347, 40.764811, '5 Av/59 St', 9.029061414768796)
# (-73.980658, 40.764664, '57 St-7 Av', 8.945167545202306)
# (-73.984139, 40.759901, '49 St', 8.83681241630772)
# (-73.986754, 40.754672, 'Times Sq-42 St', 8.425415042623767)
# (-73.98795, 40.749567, '34 St-Herald Sq', 8.437716199485127)
# (-73.988691, 40.745494, '28 St', 8.735463172185408)
# (-73.989344, 40.741303, '23 St', 9.167824403491688)
# (-73.990568, 40.735736, '14 St-Union Sq', 8.970487221533833)
# (-73.992629, 40.730328, '8 St-NYU', 9.36996211223294)
# (-73.997702, 40.724329, 'Prince St', 9.315547002248014)
# (-74.001775, 40.719527, 'Canal St', 8.929645475820754)
# (-74.006978, 40.713282, 'City Hall', 9.043714053737563)
# (-74.011029, 40.710668, 'Cortlandt St', 1)
# (-74.013342, 40.70722, 'Rector St', 8.587986828838996)
# (-74.012994, 40.703087, 'Whitehall St-South Ferry', 1)
# (-73.981824, 40.690635, 'DeKalb Av', 7.664944583625936)
# (-73.97689, 40.68446, 'Atlantic Av-Barclays Ctr', 7.277331542770628)
# (-73.972367, 40.67705, '7 Av', 9.20377915351573)
# (-73.962246, 40.661614, 'Prospect Park', 6.008185140101953)
# (-73.962982, 40.650527, 'Church Av', 5.138203244765634)
# (-73.962793, 40.635082, 'Newkirk Plaza', 3.4896190139212835)
# (-73.957734, 40.60867, 'Kings Hwy', 3.417937740879721)
# (-73.954155, 40.586896, 'Sheepshead Bay', 2.2048272985568707)
# (-73.961376, 40.577621, 'Brighton Beach', 3.0263146772416123)
# (-73.944216, 40.824783, '145 St', 6.514920991812318)
# (-73.947649, 40.817894, '135 St', 7.138622752534118)
# (-73.952343, 40.811109, '125 St', 6.498970641373971)
# (-73.954882, 40.805085, '116 St', 7.283514956247069)
# (-73.958161, 40.800603, 'Cathedral Pkwy (110 St)', 1)
# (-73.961454, 40.796092, '103 St', 7.285450885681039)
# (-73.964696, 40.791642, '96 St', 8.17726281111453)
# (-73.968916, 40.785868, '86 St', 8.494172387305651)
# (-73.972143, 40.781433, '81 St-Museum of Natural History', 8.803005845014406)
# (-73.97641, 40.775594, '72 St', 8.956933909597268)
# (-73.981736, 40.768296, '59 St-Columbus Circle', 8.740219891215215)
# (-73.985984, 40.762456, '50 St', 8.948870889203043)
# (-73.989735, 40.757308, '42 St-Port Authority Bus Terminal', 1)
# (-73.993391, 40.752287, '34 St-Penn Station', 8.393406752920015)
# (-73.998041, 40.745906, '23 St', 9.050352966097611)
# (-74.00169, 40.740893, '14 St', 1)
# (-74.000495, 40.732338, 'W 4 St-Wash Sq', 9.267911376046527)
# (-74.000495, 40.732338, 'W 4 St-Wash Sq', 9.267911376046527)
# (-74.003739, 40.726227, 'Spring St', 9.252189822035962)
# (-74.005229, 40.720824, 'Canal St', 8.989529430872205)
# (-74.009781, 40.712582, 'World Trade Center', 1)
# (-73.887138, 40.873244, 'Bedford Park Blvd', 3.9264310232068595)
# (-73.893509, 40.866978, 'Kingsbridge Rd', 3.8153488232407873)
# (-73.897749, 40.861296, 'Fordham Rd', 4.11182456819048)
# (-73.900741, 40.856093, '182-183 Sts', 3.6693076221204977)
# (-73.905227, 40.85041, 'Tremont Av', 3.4212941844789087)
# (-73.910136, 40.8459, '174-175 Sts', 3.4693050096252662)
# (-73.9134, 40.839306, '170 St', 3.8044903095287657)
# (-73.91844, 40.833771, '167 St', 3.8760763031246688)
# (-73.925651, 40.827905, '161 St-Yankee Stadium', 5.551308296643725)
# (-73.938209, 40.830135, '155 St', 6.920664796575929)
# (-73.981329, 40.758663, '47-50 Sts-Rockefeller Ctr', 8.829292964975561)
# (-73.984569, 40.754222, '42 St-Bryant Pk', 1)
# (-73.987823, 40.749719, '34 St-Herald Sq', 8.437716199485127)
# (-73.996204, 40.725297, 'Broadway-Lafayette St', 9.124383772534065)
# (-73.993753, 40.718267, 'Grand St', 8.80187447418676)
# (-73.820574, 40.709179, 'Briarwood', 2.767973181949362)
# (-73.831008, 40.714441, 'Kew Gardens-Union Tpke', 3.0150185608586804)
# (-73.837324, 40.718331, '75 Av', 3.5638212083081298)
# (-73.844521, 40.721691, 'Forest Hills-71 Av', 3.363920487638474)
# (-73.891338, 40.746644, 'Jackson Hts-Roosevelt Av', 1)
# (-73.937243, 40.748973, 'Queens Plaza', 6.287005922131483)
# (-73.946, 40.747846, 'Court Sq-23 St', 1)
# (-73.969055, 40.757552, 'Lexington Av/53 St', 1)
# (-73.975224, 40.760167, '5 Av/53 St', 9.039389290775622)
# (-73.981637, 40.762862, '7 Av', 9.096009864988636)
# (-73.981637, 40.762862, '7 Av', 9.20377915351573)
# (-73.801109, 40.702147, 'Jamaica Center-Parsons/Archer', 2.6859282547818006)
# (-73.807969, 40.700486, 'Sutphin Blvd-Archer Av-JFK Airport', 3.10712054633823)
# (-73.816859, 40.702566, 'Jamaica-Van Wyck', 3.240751255415117)
# (-73.940202, 40.750582, 'Queensboro Plaza', 6.506805224279235)

# %%
# Add subway lines and stations to fig
for route, stations in line_stations.items():
    if not stations:
        continue

    # # Sort roughly north-to-south
    stations.sort(key=lambda x: (-x[1], x[0]))
    lons = [s[0] for s in stations]
    lats = [s[1] for s in stations]
    names = [s[2] for s in stations]
    sizes = [s[3] for s in stations]

    # Subway line
    fig.add_trace(go.Scattergeo(
        lon=lons, lat=lats,
        mode="lines",
        line=dict(width=2, color=mta_colors[route]),
        name=f"Line {route}"
    ))

    # Subway stations
    fig.add_trace(go.Scattergeo(
        lon=lons, lat=lats,
        mode="markers",
        marker=dict(size=sizes, color=mta_colors[route]),
        showlegend = False
    ))

# %%
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="720"
#     src="iframe_figures/figure_54.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### Swap stations to correct route order

# %% [markdown]
# #### Fix W Line

# %%
line_stations["W"]
# Out:
# [(-73.912034, 40.775036, 'Astoria-Ditmars Blvd', 3.811295073782773),
#  (-73.917843, 40.770258, 'Astoria Blvd', 4.308446487582657),
#  (-73.921479, 40.766779, '30 Av', 4.547316187242545),
#  (-73.973347, 40.764811, '5 Av/59 St', 9.029061414768796),
#  (-73.980658, 40.764664, '57 St-7 Av', 8.945167545202306),
#  (-73.967258, 40.76266, 'Lexington Av/59 St', 1),
#  (-73.925508, 40.76182, 'Broadway', 5.041404864864728),
#  (-73.984139, 40.759901, '49 St', 8.83681241630772),
#  (-73.929575, 40.756804, '36 Av', 5.880039980794761),
#  (-73.986754, 40.754672, 'Times Sq-42 St', 8.425415042623767),
#  (-73.932755, 40.752882, '39 Av-Dutch Kills', 6.5142092807510865),
#  (-73.940202, 40.750582, 'Queensboro Plaza', 6.506805224279235),
#  (-73.98795, 40.749567, '34 St-Herald Sq', 8.437716199485127),
#  (-73.988691, 40.745494, '28 St', 8.735463172185408),
#  (-73.989344, 40.741303, '23 St', 9.167824403491688),
#  (-73.990568, 40.735736, '14 St-Union Sq', 8.970487221533833),
#  (-73.992629, 40.730328, '8 St-NYU', 9.36996211223294),
#  (-73.997702, 40.724329, 'Prince St', 9.315547002248014),
#  (-74.001775, 40.719527, 'Canal St', 8.929645475820754),
#  (-74.006978, 40.713282, 'City Hall', 9.043714053737563),
#  (-74.011029, 40.710668, 'Cortlandt St', 1),
#  (-74.013342, 40.70722, 'Rector St', 8.587986828838996),
#  (-74.012994, 40.703087, 'Whitehall St-South Ferry', 1)]

# %%
station = line_stations["W"][3]
line_stations["W"][3] = line_stations["W"][6] # Swap with 59th and 5th with Broadway
line_stations["W"][6] = station

station = line_stations["W"][4]
line_stations["W"][4] = line_stations["W"][8] # Swap with 36 ave
line_stations["W"][8] = station

station = line_stations["W"][5]
line_stations["W"][5] = line_stations["W"][10] # Swap with 39 ave
line_stations["W"][10] = station

station = line_stations["W"][6]
line_stations["W"][6] = line_stations["W"][11] # Swap with queensboro
line_stations["W"][11] = station

station = line_stations["W"][7]
line_stations["W"][7] = line_stations["W"][10] # Swap with 59th / lex
line_stations["W"][10] = station

station = line_stations["W"][8]
line_stations["W"][8] = line_stations["W"][11] # Swap with 59th / 5th
line_stations["W"][11] = station

station = line_stations["W"][9]
line_stations["W"][9] = line_stations["W"][10] # Swap with queensboro
line_stations["W"][10] = station

fournine = line_stations["W"][9]
timesquare = line_stations["W"][10]
seventhave = line_stations["W"][11]

line_stations["W"][9] = seventhave
line_stations["W"][10] = fournine
line_stations["W"][11] = timesquare

# %%
line_stations["W"]
# Out:
# [(-73.912034, 40.775036, 'Astoria-Ditmars Blvd', 3.811295073782773),
#  (-73.917843, 40.770258, 'Astoria Blvd', 4.308446487582657),
#  (-73.921479, 40.766779, '30 Av', 4.547316187242545),
#  (-73.925508, 40.76182, 'Broadway', 5.041404864864728),
#  (-73.929575, 40.756804, '36 Av', 5.880039980794761),
#  (-73.932755, 40.752882, '39 Av-Dutch Kills', 6.5142092807510865),
#  (-73.940202, 40.750582, 'Queensboro Plaza', 6.506805224279235),
#  (-73.967258, 40.76266, 'Lexington Av/59 St', 1),
#  (-73.973347, 40.764811, '5 Av/59 St', 9.029061414768796),
#  (-73.980658, 40.764664, '57 St-7 Av', 8.945167545202306),
#  (-73.984139, 40.759901, '49 St', 8.83681241630772),
#  (-73.986754, 40.754672, 'Times Sq-42 St', 8.425415042623767),
#  (-73.98795, 40.749567, '34 St-Herald Sq', 8.437716199485127),
#  (-73.988691, 40.745494, '28 St', 8.735463172185408),
#  (-73.989344, 40.741303, '23 St', 9.167824403491688),
#  (-73.990568, 40.735736, '14 St-Union Sq', 8.970487221533833),
#  (-73.992629, 40.730328, '8 St-NYU', 9.36996211223294),
#  (-73.997702, 40.724329, 'Prince St', 9.315547002248014),
#  (-74.001775, 40.719527, 'Canal St', 8.929645475820754),
#  (-74.006978, 40.713282, 'City Hall', 9.043714053737563),
#  (-74.011029, 40.710668, 'Cortlandt St', 1),
#  (-74.013342, 40.70722, 'Rector St', 8.587986828838996),
#  (-74.012994, 40.703087, 'Whitehall St-South Ferry', 1)]

# %% [markdown]
# #### Fix Line B

# %%
line_stations["B"]
# Out:
# [(-73.887138, 40.873244, 'Bedford Park Blvd', 3.9264310232068595),
#  (-73.893509, 40.866978, 'Kingsbridge Rd', 3.8153488232407873),
#  (-73.897749, 40.861296, 'Fordham Rd', 4.11182456819048),
#  (-73.900741, 40.856093, '182-183 Sts', 3.6693076221204977),
#  (-73.905227, 40.85041, 'Tremont Av', 3.4212941844789087),
#  (-73.910136, 40.8459, '174-175 Sts', 3.4693050096252662),
#  (-73.9134, 40.839306, '170 St', 3.8044903095287657),
#  (-73.91844, 40.833771, '167 St', 3.8760763031246688),
#  (-73.938209, 40.830135, '155 St', 6.920664796575929),
#  (-73.925651, 40.827905, '161 St-Yankee Stadium', 5.551308296643725),
#  (-73.944216, 40.824783, '145 St', 6.514920991812318),
#  (-73.947649, 40.817894, '135 St', 7.138622752534118),
#  (-73.952343, 40.811109, '125 St', 6.498970641373971),
#  (-73.954882, 40.805085, '116 St', 7.283514956247069),
#  (-73.958161, 40.800603, 'Cathedral Pkwy (110 St)', 1),
#  (-73.961454, 40.796092, '103 St', 7.285450885681039),
#  (-73.964696, 40.791642, '96 St', 8.17726281111453),
#  (-73.968916, 40.785868, '86 St', 8.494172387305651),
#  (-73.972143, 40.781433, '81 St-Museum of Natural History', 8.803005845014406),
#  (-73.97641, 40.775594, '72 St', 8.956933909597268),
#  (-73.981736, 40.768296, '59 St-Columbus Circle', 8.740219891215215),
#  (-73.981637, 40.762862, '7 Av', 9.20377915351573),
#  (-73.981329, 40.758663, '47-50 Sts-Rockefeller Ctr', 8.829292964975561),
#  (-73.984569, 40.754222, '42 St-Bryant Pk', 1),
#  (-73.987823, 40.749719, '34 St-Herald Sq', 8.437716199485127),
#  (-74.000495, 40.732338, 'W 4 St-Wash Sq', 9.267911376046527),
#  (-73.996204, 40.725297, 'Broadway-Lafayette St', 9.124383772534065),
#  (-73.993753, 40.718267, 'Grand St', 8.80187447418676),
#  (-73.981824, 40.690635, 'DeKalb Av', 7.664944583625936),
#  (-73.97689, 40.68446, 'Atlantic Av-Barclays Ctr', 7.277331542770628),
#  (-73.972367, 40.67705, '7 Av', 9.20377915351573),
#  (-73.962246, 40.661614, 'Prospect Park', 6.008185140101953),
#  (-73.962982, 40.650527, 'Church Av', 5.138203244765634),
#  (-73.962793, 40.635082, 'Newkirk Plaza', 3.4896190139212835),
#  (-73.957734, 40.60867, 'Kings Hwy', 3.417937740879721),
#  (-73.954155, 40.586896, 'Sheepshead Bay', 2.2048272985568707),
#  (-73.961376, 40.577621, 'Brighton Beach', 3.0263146772416123)]

# %%
# Fix the B Line
onefivefive = line_stations["B"][8]
yankee = line_stations["B"][9]

line_stations["B"][8] = yankee
line_stations["B"][9] = onefivefive

# %% [markdown]
# #### Fix E Line

# %%
line_stations["E"]
# Out:
# [(-73.981637, 40.762862, '7 Av', 9.096009864988636),
#  (-73.985984, 40.762456, '50 St', 8.948870889203043),
#  (-73.975224, 40.760167, '5 Av/53 St', 9.039389290775622),
#  (-73.969055, 40.757552, 'Lexington Av/53 St', 1),
#  (-73.989735, 40.757308, '42 St-Port Authority Bus Terminal', 1),
#  (-73.993391, 40.752287, '34 St-Penn Station', 8.393406752920015),
#  (-73.937243, 40.748973, 'Queens Plaza', 6.287005922131483),
#  (-73.946, 40.747846, 'Court Sq-23 St', 1),
#  (-73.891338, 40.746644, 'Jackson Hts-Roosevelt Av', 1),
#  (-73.998041, 40.745906, '23 St', 9.050352966097611),
#  (-74.00169, 40.740893, '14 St', 1),
#  (-74.000495, 40.732338, 'W 4 St-Wash Sq', 9.267911376046527),
#  (-74.003739, 40.726227, 'Spring St', 9.252189822035962),
#  (-73.844521, 40.721691, 'Forest Hills-71 Av', 3.363920487638474),
#  (-74.005229, 40.720824, 'Canal St', 8.989529430872205),
#  (-73.837324, 40.718331, '75 Av', 3.5638212083081298),
#  (-73.831008, 40.714441, 'Kew Gardens-Union Tpke', 3.0150185608586804),
#  (-74.009781, 40.712582, 'World Trade Center', 1),
#  (-73.820574, 40.709179, 'Briarwood', 2.767973181949362),
#  (-73.816859, 40.702566, 'Jamaica-Van Wyck', 3.240751255415117),
#  (-73.801109, 40.702147, 'Jamaica Center-Parsons/Archer', 2.6859282547818006),
#  (-73.807969,
#   40.700486,
#   'Sutphin Blvd-Archer Av-JFK Airport',
#   3.10712054633823)]

# %%
len(line_stations["E"])
# Out:
# 22

# %%
parsons = line_stations["E"][20] # Stop 0
jfk = line_stations["E"][21]     # Stop 1...
vanwyck = line_stations["E"][19]
briarwood = line_stations["E"][18]
kewgardens = line_stations["E"][16]
sevenfive = line_stations["E"][15]
foresthills = line_stations["E"][13]
rooseveltave = line_stations["E"][8]
queensplaza = line_stations["E"][6]
courtsq = line_stations["E"][7]
fiftythreelex = line_stations["E"][3]
fiftythreefifth = line_stations["E"][2]
seventhave = line_stations["E"][0]
fiftystreet = line_stations["E"][1]
portauth = line_stations["E"][4]
pennstation = line_stations["E"][5]
twentythree = line_stations["E"][9]
fourteen = line_stations["E"][10]
washsquare = line_stations["E"][11]
spring = line_stations["E"][12]
canal = line_stations["E"][14]
wtc = line_stations["E"][17]

line_stations["E"][0] = parsons
line_stations["E"][1] = jfk
line_stations["E"][2] = vanwyck
line_stations["E"][3] = briarwood
line_stations["E"][4] = kewgardens
line_stations["E"][5] = sevenfive
line_stations["E"][6] = foresthills
line_stations["E"][7] = rooseveltave
line_stations["E"][8] = queensplaza
line_stations["E"][9] = courtsq
line_stations["E"][10] = fiftythreelex
line_stations["E"][11] = fiftythreefifth
line_stations["E"][12] = seventhave
line_stations["E"][13] = fiftystreet
line_stations["E"][14] = portauth
line_stations["E"][15] = pennstation
line_stations["E"][16] = twentythree
line_stations["E"][17] = fourteen
line_stations["E"][18] = washsquare
line_stations["E"][19] = spring
line_stations["E"][20] = canal
line_stations["E"][21] = wtc

# %%
# Plot NYC boroughs

import json
import plotly.graph_objects as go
from collections import defaultdict

# Load NYC GeoJSON file
with open("Final_Data/borough.geo.json") as f:
    boroughs_geojson = json.load(f)

borough_names = [f["properties"]["BoroName"] for f in boroughs_geojson["features"]]
color_values = [1, 2, 3, 4, 5]  # dummy values

# Create base fig
fig2 = go.Figure()

fig2.add_trace(go.Choropleth(
    geojson=boroughs_geojson,
    locations=borough_names,
    z=color_values,
    featureidkey="properties.BoroName",
    colorscale=["lightgray", "darkgray"],
    marker_line_width=0.5,
    marker_line_color="white",
    showscale=False
))

# Update locations and layout
fig2.update_geos(
    fitbounds="locations",
    visible=False
)
fig2.update_layout(
    height=700,
    margin={"r":0,"t":0,"l":0,"b":0}
)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="720"
#     src="iframe_figures/figure_63.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
line_stations.items()
# Out:
# dict_items([('W', [(-73.912034, 40.775036, 'Astoria-Ditmars Blvd', 3.811295073782773), (-73.917843, 40.770258, 'Astoria Blvd', 4.308446487582657), (-73.921479, 40.766779, '30 Av', 4.547316187242545), (-73.925508, 40.76182, 'Broadway', 5.041404864864728), (-73.929575, 40.756804, '36 Av', 5.880039980794761), (-73.932755, 40.752882, '39 Av-Dutch Kills', 6.5142092807510865), (-73.940202, 40.750582, 'Queensboro Plaza', 6.506805224279235), (-73.967258, 40.76266, 'Lexington Av/59 St', 1), (-73.973347, 40.764811, '5 Av/59 St', 9.029061414768796), (-73.980658, 40.764664, '57 St-7 Av', 8.945167545202306), (-73.984139, 40.759901, '49 St', 8.83681241630772), (-73.986754, 40.754672, 'Times Sq-42 St', 8.425415042623767), (-73.98795, 40.749567, '34 St-Herald Sq', 8.437716199485127), (-73.988691, 40.745494, '28 St', 8.735463172185408), (-73.989344, 40.741303, '23 St', 9.167824403491688), (-73.990568, 40.735736, '14 St-Union Sq', 8.970487221533833), (-73.992629, 40.730328, '8 St-NYU', 9.36996211223294), (-73.997702, 40.724329, 'Prince St', 9.315547002248014), (-74.001775, 40.719527, 'Canal St', 8.929645475820754), (-74.006978, 40.713282, 'City Hall', 9.043714053737563), (-74.011029, 40.710668, 'Cortlandt St', 1), (-74.013342, 40.70722, 'Rector St', 8.587986828838996), (-74.012994, 40.703087, 'Whitehall St-South Ferry', 1)]), ('B', [(-73.887138, 40.873244, 'Bedford Park Blvd', 3.9264310232068595), (-73.893509, 40.866978, 'Kingsbridge Rd', 3.8153488232407873), (-73.897749, 40.861296, 'Fordham Rd', 4.11182456819048), (-73.900741, 40.856093, '182-183 Sts', 3.6693076221204977), (-73.905227, 40.85041, 'Tremont Av', 3.4212941844789087), (-73.910136, 40.8459, '174-175 Sts', 3.4693050096252662), (-73.9134, 40.839306, '170 St', 3.8044903095287657), (-73.91844, 40.833771, '167 St', 3.8760763031246688), (-73.925651, 40.827905, '161 St-Yankee Stadium', 5.551308296643725), (-73.938209, 40.830135, '155 St', 6.920664796575929), (-73.944216, 40.824783, '145 St', 6.514920991812318), (-73.947649, 40.817894, '135 St', 7.138622752534118), (-73.952343, 40.811109, '125 St', 6.498970641373971), (-73.954882, 40.805085, '116 St', 7.283514956247069), (-73.958161, 40.800603, 'Cathedral Pkwy (110 St)', 1), (-73.961454, 40.796092, '103 St', 7.285450885681039), (-73.964696, 40.791642, '96 St', 8.17726281111453), (-73.968916, 40.785868, '86 St', 8.494172387305651), (-73.972143, 40.781433, '81 St-Museum of Natural History', 8.803005845014406), (-73.97641, 40.775594, '72 St', 8.956933909597268), (-73.981736, 40.768296, '59 St-Columbus Circle', 8.740219891215215), (-73.981637, 40.762862, '7 Av', 9.20377915351573), (-73.981329, 40.758663, '47-50 Sts-Rockefeller Ctr', 8.829292964975561), (-73.984569, 40.754222, '42 St-Bryant Pk', 1), (-73.987823, 40.749719, '34 St-Herald Sq', 8.437716199485127), (-74.000495, 40.732338, 'W 4 St-Wash Sq', 9.267911376046527), (-73.996204, 40.725297, 'Broadway-Lafayette St', 9.124383772534065), (-73.993753, 40.718267, 'Grand St', 8.80187447418676), (-73.981824, 40.690635, 'DeKalb Av', 7.664944583625936), (-73.97689, 40.68446, 'Atlantic Av-Barclays Ctr', 7.277331542770628), (-73.972367, 40.67705, '7 Av', 9.20377915351573), (-73.962246, 40.661614, 'Prospect Park', 6.008185140101953), (-73.962982, 40.650527, 'Church Av', 5.138203244765634), (-73.962793, 40.635082, 'Newkirk Plaza', 3.4896190139212835), (-73.957734, 40.60867, 'Kings Hwy', 3.417937740879721), (-73.954155, 40.586896, 'Sheepshead Bay', 2.2048272985568707), (-73.961376, 40.577621, 'Brighton Beach', 3.0263146772416123)]), ('E', [(-73.801109, 40.702147, 'Jamaica Center-Parsons/Archer', 2.6859282547818006), (-73.807969, 40.700486, 'Sutphin Blvd-Archer Av-JFK Airport', 3.10712054633823), (-73.816859, 40.702566, 'Jamaica-Van Wyck', 3.240751255415117), (-73.820574, 40.709179, 'Briarwood', 2.767973181949362), (-73.831008, 40.714441, 'Kew Gardens-Union Tpke', 3.0150185608586804), (-73.837324, 40.718331, '75 Av', 3.5638212083081298), (-73.844521, 40.721691, 'Forest Hills-71 Av', 3.363920487638474), (- ...

# %%
# Add subway lines and stations
for route, stations in line_stations.items():
    if not stations:
        continue

    lons = [s[0] for s in stations]
    lats = [s[1] for s in stations]
    names = [s[2] for s in stations]
    sizes = [s[3] for s in stations]

    # Subway line
    fig2.add_trace(go.Scattergeo(
        lon=lons, lat=lats,
        mode="lines",
        line=dict(width=2, color=mta_colors[route]),
        name=f"Line {route}"
    ))

    # Subway stations
    fig2.add_trace(go.Scattergeo(
        lon=lons, lat=lats,
        mode="markers",
        marker=dict(size=sizes, color=mta_colors[route]),
        showlegend = False
    ))

fig2.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="720"
#     src="iframe_figures/figure_65.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## Add routes with least creative availability

# %%
least_avail = {
    "A": "#000000",
    "Z": "#000000",
    "N": "#000000", 
} 

for feature in stations_geojson["features"]:
    coords = feature["geometry"]["coordinates"]  # [lon, lat]
    props = feature["properties"]
    routes = props["daytime_routes"].split()

    for route in routes:
        if route in least_avail.keys():
            lon, lat = coords[0], coords[1]
            stop_name = props["stop_name"]
            size = 1
            try: 
                size = scores.filter( (col("stop_name") == stop_name) & (col("Route") == route)).select(col("median(avail_score)")).first()["median(avail_score)"]            
                size = size / 10.0
            except:
                size = 1
            val = (lon, lat, stop_name, size)

            if route in line_stations.keys():
                line_stations[route].append(val)
            else:
                line_stations[route] = [val]

# %% [markdown]
# ### Fix Line Z

# %%
line_stations["Z"]
# Out:
# [(-73.828294, 40.700492, '121 St', 2.5331691809809826),
#  (-73.84433, 40.695178, '104 St', 1.889710738630982),
#  (-73.851576, 40.693879, 'Woodhaven Blvd', 1.7510227327848995),
#  (-73.867139, 40.691324, '75 St-Elderts Ln', 2.8534168375547964),
#  (-73.873785, 40.683194, 'Crescent St', 2.876580666913992),
#  (-73.880039, 40.68141, 'Norwood Av', 3.375617451020399),
#  (-73.891688, 40.678024, 'Van Siclen Av', 3.277315483517816),
#  (-73.898654, 40.676992, 'Alabama Av', 1),
#  (-73.904512, 40.679498, 'Broadway Junction', 3.976875063008483),
#  (-73.910456, 40.682893, 'Chauncey St', 5.891317197187838),
#  (-73.92227, 40.68963, 'Gates Av', 5.965619631390252),
#  (-73.935657, 40.697207, 'Myrtle Av', 6.3726930987301005),
#  (-73.957757, 40.708359, 'Marcy Av', 6.297225787930145),
#  (-73.987437, 40.718315, 'Delancey St-Essex St', 1),
#  (-73.993915, 40.72028, 'Bowery', 9.188753423292876),
#  (-73.999892, 40.718092, 'Canal St', 8.805328535930043),
#  (-74.003401, 40.713243, 'Chambers St', 1),
#  (-74.007582, 40.710374, 'Fulton St', 8.44450947954444),
#  (-74.011056, 40.706476, 'Broad St', 8.700611178766104),
#  (-73.801109, 40.702147, 'Jamaica Center-Parsons/Archer', 2.6859282547818006),
#  (-73.807969,
#   40.700486,
#   'Sutphin Blvd-Archer Av-JFK Airport',
#   3.10712054633823)]

# %%
parsons = line_stations["Z"][-2]
jfk = line_stations["Z"][-1]
line_stations["Z"].insert(0, parsons)
line_stations["Z"].insert(1, jfk)
line_stations["Z"].pop(-2)
line_stations["Z"].pop(-1)
# Out:
# (-73.807969, 40.700486, 'Sutphin Blvd-Archer Av-JFK Airport', 3.10712054633823)

# %%
line_stations["Z"]
# Out:
# [(-73.801109, 40.702147, 'Jamaica Center-Parsons/Archer', 2.6859282547818006),
#  (-73.807969,
#   40.700486,
#   'Sutphin Blvd-Archer Av-JFK Airport',
#   3.10712054633823),
#  (-73.828294, 40.700492, '121 St', 2.5331691809809826),
#  (-73.84433, 40.695178, '104 St', 1.889710738630982),
#  (-73.851576, 40.693879, 'Woodhaven Blvd', 1.7510227327848995),
#  (-73.867139, 40.691324, '75 St-Elderts Ln', 2.8534168375547964),
#  (-73.873785, 40.683194, 'Crescent St', 2.876580666913992),
#  (-73.880039, 40.68141, 'Norwood Av', 3.375617451020399),
#  (-73.891688, 40.678024, 'Van Siclen Av', 3.277315483517816),
#  (-73.898654, 40.676992, 'Alabama Av', 1),
#  (-73.904512, 40.679498, 'Broadway Junction', 3.976875063008483),
#  (-73.910456, 40.682893, 'Chauncey St', 5.891317197187838),
#  (-73.92227, 40.68963, 'Gates Av', 5.965619631390252),
#  (-73.935657, 40.697207, 'Myrtle Av', 6.3726930987301005),
#  (-73.957757, 40.708359, 'Marcy Av', 6.297225787930145),
#  (-73.987437, 40.718315, 'Delancey St-Essex St', 1),
#  (-73.993915, 40.72028, 'Bowery', 9.188753423292876),
#  (-73.999892, 40.718092, 'Canal St', 8.805328535930043),
#  (-74.003401, 40.713243, 'Chambers St', 1),
#  (-74.007582, 40.710374, 'Fulton St', 8.44450947954444),
#  (-74.011056, 40.706476, 'Broad St', 8.700611178766104)]

# %% [markdown]
# ### Fix Line N

# %%
line_stations["N"]
# Out:
# [(-73.912034, 40.775036, 'Astoria-Ditmars Blvd', 3.811295073782773),
#  (-73.917843, 40.770258, 'Astoria Blvd', 4.308446487582657),
#  (-73.921479, 40.766779, '30 Av', 4.547316187242545),
#  (-73.925508, 40.76182, 'Broadway', 5.041404864864728),
#  (-73.929575, 40.756804, '36 Av', 5.880039980794761),
#  (-73.932755, 40.752882, '39 Av-Dutch Kills', 6.5142092807510865),
#  (-73.967258, 40.76266, 'Lexington Av/59 St', 1),
#  (-73.973347, 40.764811, '5 Av/59 St', 9.029061414768796),
#  (-73.980658, 40.764664, '57 St-7 Av', 8.945167545202306),
#  (-73.984139, 40.759901, '49 St', 8.83681241630772),
#  (-73.986754, 40.754672, 'Times Sq-42 St', 8.425415042623767),
#  (-73.98795, 40.749567, '34 St-Herald Sq', 8.437716199485127),
#  (-73.990568, 40.735736, '14 St-Union Sq', 8.970487221533833),
#  (-74.00046, 40.718383, 'Canal St', 8.805328535930043),
#  (-73.97881, 40.683666, 'Atlantic Av-Barclays Ctr', 7.117495477196857),
#  (-74.003549, 40.655144, '36 St', 5.308374636532221),
#  (-74.017881, 40.641362, '59 St', 3.259244455203388),
#  (-73.981233, 40.577422, 'Coney Island-Stillwell Av', 3.6883480140555904),
#  (-74.011719, 40.635064, '8 Av', 2.9428416766166716),
#  (-74.005351, 40.631386, 'Fort Hamilton Pkwy', 2.5836206111972713),
#  (-73.996353, 40.624842, 'New Utrecht Av', 1),
#  (-73.990414, 40.620671, '18 Av', 2.384561571692957),
#  (-73.985026, 40.61741, '20 Av', 2.5003569105681),
#  (-73.981848, 40.611815, 'Bay Pkwy', 2.6393587762576223),
#  (-73.980353, 40.603923, 'Kings Hwy', 2.655747971989226),
#  (-73.979137, 40.597473, 'Avenue U', 2.2797393310305893),
#  (-73.97823, 40.592721, '86 St', 2.3026856080440874),
#  (-73.940202, 40.750582, 'Queensboro Plaza', 6.506805224279235)]

# %%
len(line_stations["N"])
# Out:
# 28

# %%
queensboro = line_stations["N"][-1]
line_stations["N"].insert(6, queensboro)
line_stations["N"].pop(-1)

coneyisland = line_stations["N"][18]
line_stations["N"].pop(18)
line_stations["N"].append(coneyisland)

# %%
line_stations["N"]
# Out:
# [(-73.912034, 40.775036, 'Astoria-Ditmars Blvd', 3.811295073782773),
#  (-73.917843, 40.770258, 'Astoria Blvd', 4.308446487582657),
#  (-73.921479, 40.766779, '30 Av', 4.547316187242545),
#  (-73.925508, 40.76182, 'Broadway', 5.041404864864728),
#  (-73.929575, 40.756804, '36 Av', 5.880039980794761),
#  (-73.932755, 40.752882, '39 Av-Dutch Kills', 6.5142092807510865),
#  (-73.940202, 40.750582, 'Queensboro Plaza', 6.506805224279235),
#  (-73.967258, 40.76266, 'Lexington Av/59 St', 1),
#  (-73.973347, 40.764811, '5 Av/59 St', 9.029061414768796),
#  (-73.980658, 40.764664, '57 St-7 Av', 8.945167545202306),
#  (-73.984139, 40.759901, '49 St', 8.83681241630772),
#  (-73.986754, 40.754672, 'Times Sq-42 St', 8.425415042623767),
#  (-73.98795, 40.749567, '34 St-Herald Sq', 8.437716199485127),
#  (-73.990568, 40.735736, '14 St-Union Sq', 8.970487221533833),
#  (-74.00046, 40.718383, 'Canal St', 8.805328535930043),
#  (-73.97881, 40.683666, 'Atlantic Av-Barclays Ctr', 7.117495477196857),
#  (-74.003549, 40.655144, '36 St', 5.308374636532221),
#  (-74.017881, 40.641362, '59 St', 3.259244455203388),
#  (-74.011719, 40.635064, '8 Av', 2.9428416766166716),
#  (-74.005351, 40.631386, 'Fort Hamilton Pkwy', 2.5836206111972713),
#  (-73.996353, 40.624842, 'New Utrecht Av', 1),
#  (-73.990414, 40.620671, '18 Av', 2.384561571692957),
#  (-73.985026, 40.61741, '20 Av', 2.5003569105681),
#  (-73.981848, 40.611815, 'Bay Pkwy', 2.6393587762576223),
#  (-73.980353, 40.603923, 'Kings Hwy', 2.655747971989226),
#  (-73.979137, 40.597473, 'Avenue U', 2.2797393310305893),
#  (-73.97823, 40.592721, '86 St', 2.3026856080440874),
#  (-73.981233, 40.577422, 'Coney Island-Stillwell Av', 3.6883480140555904)]

# %%
for route, stations in line_stations.items():
    if not stations:
        continue
    if route in mta_colors.keys():
        continue

    lons = [s[0] for s in stations]
    lats = [s[1] for s in stations]
    names = [s[2] for s in stations]
    sizes = [s[3] for s in stations]

    # Subway line
    fig2.add_trace(go.Scattergeo(
        lon=lons, lat=lats,
        mode="lines",
        line=dict(width=2, color=least_avail[route], dash = "dash"),
        name=f"Line {route}",
        opacity = 0.3
    ))

    # Subway stations
    fig2.add_trace(go.Scattergeo(
        lon=lons, lat=lats,
        mode="markers",
        marker=dict(size=sizes, color=least_avail[route]),
        showlegend = False,
        text=[s[2] for s in stations],  # stop names
        hoverinfo="text",               # only show text
        opacity = 0.3
    ))

# %%
fig2.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="720"
#     src="iframe_figures/figure_75.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
